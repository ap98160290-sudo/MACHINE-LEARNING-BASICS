# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
ax=pd.read_csv("c:\\Users\\admin\\Downloads\\Drug.csv")

# %%
ax.head(2)
# Out:
#    Age Sex    BP Cholesterol        Na         K   Drug
# 0   23   F  HIGH        HIGH  0.792535  0.031258  drugY
# 1   47   M   LOW        HIGH  0.739309  0.056468  drugC

# %%
ax.head(2)
# Out:
#    Age Sex    BP Cholesterol        Na         K   Drug
# 0   23   F  HIGH        HIGH  0.792535  0.031258  drugY
# 1   47   M   LOW        HIGH  0.739309  0.056468  drugC

# %%
le=LabelEncoder()
ax["Sex"]=le.fit_transform(ax["Sex"])
ax["BP"]=le.fit_transform(ax["BP"])
ax["Cholesterol"]=le.fit_transform(ax["Cholesterol"])

# %%
ax.head(2)
# Out:
#    Age  Sex  BP  Cholesterol        Na         K   Drug
# 0   23    0   0            0  0.792535  0.031258  drugY
# 1   47    1   1            0  0.739309  0.056468  drugC

# %%
x=ax.drop("Drug",axis=1)
y=ax["Drug"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression(max_iter=1000)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
print(y_test.head())
x_test.head()
# Out:
# 95     drugX
# 15     drugY
# 30     drugX
# 158    drugC
# 128    drugY
# Name: Drug, dtype: object
#      Age  Sex  BP  Cholesterol        Na         K
# 95    36    1   1            1  0.527650  0.046188
# 15    16    0   0            1  0.833837  0.053742
# 30    18    0   2            1  0.553567  0.063265
# 158   59    0   1            0  0.640455  0.061320
# 128   47    1   1            1  0.847730  0.025274

# %%
new_data=pd.DataFrame([[18,0,2,1,0.553567,0.063265]],columns=["Age","Sex","BP","Cholesterol","Na","K"])
lr.predict(new_data)
# Out:
# array(['drugX'], dtype=object)

# %%
y_pred=lr.predict(x_test)

# %%
print("ACCURACY SCORE",accuracy_score(y_pred,y_test))
# Out:
# ACCURACY SCORE 0.5

# %% [markdown]
# ## WE ARE TRAINING OUR MODEL ON THE SAME DATASET AGAIN TO CHECK THE ACCURACY SCORE CHANGE OR NOT.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
df=pd.read_csv("c:\\Users\\admin\\Downloads\\Drug.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Age          200 non-null    int64
#  1   Sex          200 non-null    object
#  2   BP           200 non-null    object
#  3   Cholesterol  200 non-null    object
#  4   Na           200 non-null    float64
#  5   K            200 non-null    float64
#  6   Drug         200 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#               Age          Na           K
# count  200.000000  200.000000  200.000000
# mean    44.315000    0.697095    0.050174
# std     16.544315    0.118907    0.017611
# min     15.000000    0.500169    0.020022
# 25%     31.000000    0.583887    0.035054
# 50%     45.000000    0.721853    0.049663
# 75%     58.000000    0.801494    0.066000
# max     74.000000    0.896056    0.079788

# %%
df.isnull().sum()
# Out:
# Age            0
# Sex            0
# BP             0
# Cholesterol    0
# Na             0
# K              0
# Drug           0
# dtype: int64

# %%
import seaborn as sns 
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
sns.countplot(x="Age",hue="Drug",data=ax)
plt.subplot(2,2,2)
sns.countplot(x="Sex",hue="Drug",data=ax)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
df.head(2)
# Out:
#    Age Sex    BP Cholesterol        Na         K   Drug
# 0   23   F  HIGH        HIGH  0.792535  0.031258  drugY
# 1   47   M   LOW        HIGH  0.739309  0.056468  drugC

# %%
le=LabelEncoder()

# %%
df["Sex"]=le.fit_transform(df["Sex"])
df["BP"]=le.fit_transform(df["BP"])
df["Cholesterol"]=le.fit_transform(df["Cholesterol"])

# %%
df.head(2)
# Out:
#    Age  Sex  BP  Cholesterol        Na         K   Drug
# 0   23    0   0            0  0.792535  0.031258  drugY
# 1   47    1   1            0  0.739309  0.056468  drugC

# %%
x=df.drop("Drug",axis=1)
y=ax["Drug"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr=LogisticRegression(max_iter=1000)
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_predd=lr.predict(x_test)

# %%
print("ACCURACY SCORE",accuracy_score(y_test,y_pred))
# Out:
# ACCURACY SCORE 0.5

# %%
xy=pd.read_csv("c:\\Users\\admin\\Downloads\\Drug.csv")

# %%
xy=xy.drop(columns=["Na","K"])

# %%
xy.head()
# Out:
#    Age Sex      BP Cholesterol   Drug
# 0   23   F    HIGH        HIGH  drugY
# 1   47   M     LOW        HIGH  drugC
# 2   47   M     LOW        HIGH  drugC
# 3   28   F  NORMAL        HIGH  drugX
# 4   61   F     LOW        HIGH  drugY

# %%
xy["Sex"]=le.fit_transform(xy["Sex"])

# %%
xy["BP"]=le.fit_transform(xy["BP"])

# %%
xy["Cholesterol"]=le.fit_transform(xy["Cholesterol"])

# %%
x=xy.drop("Drug",axis=1)
y=xy["Drug"]

# %%
x.head(2)
# Out:
#    Age  Sex  BP  Cholesterol
# 0   23    0   0            0
# 1   47    1   1            0

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_predd=lr.predict(x_test)

# %%
print("ACCURACY SCORE",accuracy_score(y_predd,y_test))
# Out:
# ACCURACY SCORE 0.45
